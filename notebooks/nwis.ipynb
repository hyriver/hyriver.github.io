# %% [markdown]
# # River Discharge

# %%
import pandas as pd
import xarray as xr

import pydaymet as daymet
import pygeohydro as gh
from pygeohydro import NWIS, plot

# %%
_ = xr.set_options(display_expand_attrs=False)

# %% [markdown]
# We can explore the available NWIS stations within a bounding box using ``interactive_map`` function. It returns an interactive map and by clicking on an station some of the most important properties of stations are shown so you can decide which station(s) to choose from.

# %%
bbox = (-69.5, 45, -69, 45.5)

# %%
nwis_kwds = {"hasDataTypeCd": "dv", "outputDataTypeCd": "dv", "parameterCd": "00060"}
gh.interactive_map(bbox, nwis_kwds=nwis_kwds)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad610994c381331526da45623e90e407 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad610994c381331526da45623e90e407&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ad610994c381331526da45623e90e407 = L.map(
#                 &quot;map_ad610994c381331526da45623e90e407&quot;,
#                 {
#                     center: [45.25, -69.25],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9e667d57f3d3a2a178c6189f7922e72 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad610994c381331526da45623e90e407);
#
#
#             var marker_4d3cdfa7dc8596ee6cd2ce3aa5835f28 = L.marker(
#                 [45.1844444, -69.4522222],
#                 {}
#             ).addTo(map_ad610994c381331526da45623e90e407);
#
#
#             var icon_7af587781a46f437357cb3af6e570c96 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4d3cdfa7dc8596ee6cd2ce3aa5835f28.setIcon(icon_7af587781a46f437357cb3af6e570c96);
#
#
#         var popup_00f8b516e8eee0ccb7bf4d7e82905e82 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#             var html_a3838975c5da91d2840133a858826930 = $(`&lt;div id=&quot;html_a3838975c5da91d2840133a858826930&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Site No.&lt;/strong&gt;: 01031450&lt;br&gt;&lt;strong&gt;Station Name&lt;/strong&gt;: Kingsbury Stream At Abbot Village, Maine&lt;br&gt;&lt;strong&gt;Coordinate&lt;/strong&gt;: (-69.4522222, 45.1844444)&lt;br&gt;&lt;strong&gt;Altitude&lt;/strong&gt;: 423.0 ft above NGVD29&lt;br&gt;&lt;strong&gt;HUC8&lt;/strong&gt;: 01020004&lt;br&gt;&lt;strong&gt;Drainage Area (NWIS)&lt;/strong&gt;: 95.4 sqmi&lt;br&gt;&lt;strong&gt;Contributing Drainage Area (NWIS)&lt;/strong&gt;: 95.4 sqmi&lt;br&gt;&lt;strong&gt;Drainage Area (GagesII)&lt;/strong&gt;: 239.0922 sqkm&lt;br&gt;&lt;strong&gt;HCDN 2009&lt;/strong&gt;: False&lt;br&gt;&lt;a href=&quot;https://waterdata.usgs.gov/nwis/inventory?agency_code=USGS&amp;site_no=01031450&quot; target=&quot;_blank&quot;&gt;More on USGS Website&lt;/div&gt;`)[0];
#             popup_00f8b516e8eee0ccb7bf4d7e82905e82.setContent(html_a3838975c5da91d2840133a858826930);
#
#
#         marker_4d3cdfa7dc8596ee6cd2ce3aa5835f28.bindPopup(popup_00f8b516e8eee0ccb7bf4d7e82905e82)
#         ;
#
#
#
#
#             var marker_6369fa2a4bf820b13fdef6e788ab00c2 = L.marker(
#                 [45.175, -69.3147222],
#                 {}
#             ).addTo(map_ad610994c381331526da45623e90e407);
#
#
#             var icon_90353c851c121e2c0cfadb9200f00478 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6369fa2a4bf820b13fdef6e788ab00c2.setIcon(icon_90353c851c121e2c0cfadb9200f00478);
#
#
#         var popup_2ad840fe7ce03470f95dfe032f16c2b4 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#             var html_5fbcb303f618b2ad015ec834a585192a = $(`&lt;div id=&quot;html_5fbcb303f618b2ad015ec834a585192a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Site No.&lt;/strong&gt;: 01031500&lt;br&gt;&lt;strong&gt;Station Name&lt;/strong&gt;: Piscataquis River Near Dover-Foxcroft, Maine&lt;br&gt;&lt;strong&gt;Coordinate&lt;/strong&gt;: (-69.3147222, 45.175)&lt;br&gt;&lt;strong&gt;Altitude&lt;/strong&gt;: 358.47 ft above NGVD29&lt;br&gt;&lt;strong&gt;HUC8&lt;/strong&gt;: 01020004&lt;br&gt;&lt;strong&gt;Drainage Area (NWIS)&lt;/strong&gt;: 298.0 sqmi&lt;br&gt;&lt;strong&gt;Contributing Drainage Area (NWIS)&lt;/strong&gt;: 298.0 sqmi&lt;br&gt;&lt;strong&gt;Drainage Area (GagesII)&lt;/strong&gt;: 769.0482 sqkm&lt;br&gt;&lt;strong&gt;HCDN 2009&lt;/strong&gt;: True&lt;br&gt;&lt;a href=&quot;https://waterdata.usgs.gov/nwis/inventory?agency_code=USGS&amp;site_no=01031500&quot; target=&quot;_blank&quot;&gt;More on USGS Website&lt;/div&gt;`)[0];
#             popup_2ad840fe7ce03470f95dfe032f16c2b4.setContent(html_5fbcb303f618b2ad015ec834a585192a);
#
#
#         marker_6369fa2a4bf820b13fdef6e788ab00c2.bindPopup(popup_2ad840fe7ce03470f95dfe032f16c2b4)
#         ;
#
#
#
#
#             var marker_bc601be2b1b066f5fd089010ced5de72 = L.marker(

# %% [markdown]
# We can get more information about these stations using the `get_info` function from `NWIS` class.

# %%
nwis = NWIS()
query = {
    "bBox": ",".join(f"{b:.06f}" for b in bbox),
    "hasDataTypeCd": "dv",
    "outputDataTypeCd": "dv",
}
info_box = nwis.get_info(query)

# %% [markdown]
# Now, let's select all the stations that their daily mean streamflow data are available between 2000-01-01 and 2010-12-31.

# %%
dates = ("2000-01-01", "2010-12-31")
stations = info_box[
    (info_box.begin_date <= dates[0]) & (info_box.end_date >= dates[1])
].site_no.tolist()

# %% [markdown]
# One of the useful information in the database in Hydro-Climatic Data Network - 2009 (HCDN-2009) flag. This flag shows whether the station is natural (True) or affected by human activities (False). If an station is not available in the HCDN dataset `None` is returned.

# %%
query = {
    "site": ",".join(stations),
    "hasDataTypeCd": "dv",
    "outputDataTypeCd": "dv",
}
info = nwis.get_info(query, expanded=True)
info.set_index("site_no").hcdn_2009
# Out:
# site_no
# 01031450           False
# 01031500            True
# 01031500            True
# 01031500            True
# 01031500            True
# 01033000           False
# 451031069185301    False
# 451105069270801    False
# Name: hcdn_2009, dtype: bool

# %% [markdown]
# We can get the daily mean streamflow for these stations using the ``get_streamflow`` function. This function has a flag to return the data mm/day rather than the default `cms` which is useful for hydrolgy models and plotting hydrologic signatures.

# %%
qobs = nwis.get_streamflow(stations, dates, mmd=False)
# Out:
# Dropped 1 stations since they don't have discharge data from 2000-01-01 to 2010-12-31.

# %% [markdown]
# By default, `get_streamflow` returns a `pandas.DataFrame` that has an `attrs` method containing metadata for all the stations.

# %% [markdown]
# Moreover, we can get the same data as `xarray.Dataset` as follows:

# %%
qobs_ds = nwis.get_streamflow(stations, dates, mmd=False, to_xarray=True)
qobs_ds
# Out:
# Dropped 1 stations since they don't have discharge data from 2000-01-01 to 2010-12-31.
# <xarray.Dataset>
# Dimensions:       (time: 4018, station_id: 2)
# Coordinates:
#   * time          (time) datetime64[ns] 2000-01-01T05:00:00 ... 2010-12-31T05...
#   * station_id    (station_id) object 'USGS-01031450' 'USGS-01031500'
# Data variables:
#     discharge     (time, station_id) float64 2.039 5.975 1.841 ... 4.389 12.6
#     station_nm    (station_id) <U44 'Kingsbury Stream At Abbot Village, Maine...
#     dec_lat_va    (station_id) float64 45.18 45.17
#     dec_long_va   (station_id) float64 -69.45 -69.31
#     alt_va        (station_id) float64 423.0 358.5
#     alt_acy_va    (station_id) float64 0.01 0.01
#     alt_datum_cd  (station_id) <U6 'NGVD29' 'NGVD29'
#     huc_cd        (station_id) <U8 '01020004' '01020004'
#     begin_date    (station_id) <U10 '1997-07-26' '1902-10-01'
#     end_date      (station_id) <U10 '2022-05-11' '2022-05-11'
# Attributes: (1)

# %% [markdown]
# Then we can use the ``signatures`` function to plot hydrologic signatures of the streamflow. Note that the input time series should be in mm/day. This function has argument, `output`, for saving the plot as a `png` file.

# %%
plot.signatures(qobs, output="_static/example_plots_signatures.png")
# Out:
# Figure(nrows=2, ncols=4, refwidth=6.5, refheight=2.2)

# %% [markdown]
# This function also can show precipitation data as a bar plot. Let's use [PyDaymet](https://github.com/cheginit/pydaymet) to get the precipitation at the NWIS stations location.

# %%
sid = "01031500"
coords = tuple(info[info.site_no == sid][["dec_long_va", "dec_lat_va"]].to_numpy()[0])
prcp = daymet.get_bycoords(coords, dates, variables="prcp", ssl=False)
qobs.index = pd.to_datetime(qobs.index.strftime("%Y-%m-%d"))

# %%
plot.signatures(qobs[f"USGS-{sid}"], prcp, title=f"Streamflow Observations for USGS-{sid}")
# Out:
# Figure(nrows=2, ncols=4, refwidth=6.5, refheight=2.2)

# %% [markdown]
# We can also get instantaneous streamflow data using `get_streamflow`. This method assumes that the input dates are in UTC time zone and returns the data in UTC time zone as well.

# %%
qobs = nwis.get_streamflow("01646500", ("2005-01-01 12:00", "2005-01-12 15:00"), freq="iv")
_ = qobs.plot(figsize=(7, 3.5))
